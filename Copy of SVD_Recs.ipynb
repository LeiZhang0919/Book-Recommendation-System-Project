# %%
# %%time
import pandas as pd
it = pd.read_csv("/content/drive/MyDrive/cpe/goodreads_interactions.csv")
# Out:
# CPU times: user 55.2 s, sys: 34 s, total: 1min 29s
# Wall time: 1min 42s

# %%
master = it[it["is_read"] == 1][["user_id", "book_id", "rating"]]
it = 0

# %%
from sklearn.model_selection import train_test_split
import numpy as np
train, test = train_test_split(np.arange(master.shape[0]), test_size=0.2, random_state=42, shuffle = True)

# %%
train,val = train_test_split(train, test_size=0.2, random_state=42, shuffle = True)

# %%
# !pip install git+https://github.com/gbolmier/funk-svd
from funk_svd import SVD
svd = SVD(learning_rate=0.001, regularization=0.005, n_epochs=100, n_factors=15, min_rating=0, max_rating=5)
# Out:
# Collecting git+https://github.com/gbolmier/funk-svd
#   Cloning https://github.com/gbolmier/funk-svd to /tmp/pip-req-build-izcm_zrm
#   Running command git clone -q https://github.com/gbolmier/funk-svd /tmp/pip-req-build-izcm_zrm
# Requirement already satisfied: numba>=0.38.0 in /usr/local/lib/python3.6/dist-packages (from funk-svd==0.0.1.dev1) (0.48.0)
# Requirement already satisfied: numpy>=1.14.3 in /usr/local/lib/python3.6/dist-packages (from funk-svd==0.0.1.dev1) (1.18.5)
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.6/dist-packages (from funk-svd==0.0.1.dev1) (1.1.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from numba>=0.38.0->funk-svd==0.0.1.dev1) (50.3.2)
# Requirement already satisfied: llvmlite<0.32.0,>=0.31.0dev0 in /usr/local/lib/python3.6/dist-packages (from numba>=0.38.0->funk-svd==0.0.1.dev1) (0.31.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->funk-svd==0.0.1.dev1) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->funk-svd==0.0.1.dev1) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23.0->funk-svd==0.0.1.dev1) (1.15.0)
# Building wheels for collected packages: funk-svd
#   Building wheel for funk-svd (setup.py) ... done
#   Created wheel for funk-svd: filename=funk_svd-0.0.1.dev1-cp36-none-any.whl size=8597 sha256=c2da25e9c13e1799627344389464175094bb7f77336b6eff5e4bdfba3e75579f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-92c29_ds/wheels/66/f1/cb/e8147525b73388cc0bd5588c915e731ab65aba9a968e3ba455
# Successfully built funk-svd
# Installing collected packages: funk-svd
# Successfully installed funk-svd-0.0.1.dev1

# %%
master.columns = ["u_id", "i_id", "rating"]

# %%
# %%time
tr = master.iloc[train]
print("Train Allocated")
vl = master.iloc[val]
print("Val Allocated")
tt = master.iloc[test]
print("Test Allocated")
# Out:
# Train Allocated
# Val Allocated
# Test Allocated
# CPU times: user 13.5 s, sys: 783 ms, total: 14.2 s
# Wall time: 14.2 s

# %%
svd.fit(X=tr, X_val=vl, early_stopping=True, shuffle=False)
# Out:
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 1.68 - val_rmse: 1.30 - val_mae: 0.97 - took 20.5 sec
# Epoch 2/100  | val_loss: 1.61 - val_rmse: 1.27 - val_mae: 0.95 - took 20.1 sec
# Epoch 3/100  | val_loss: 1.57 - val_rmse: 1.25 - val_mae: 0.93 - took 19.8 sec
# Epoch 4/100  | val_loss: 1.55 - val_rmse: 1.24 - val_mae: 0.92 - took 19.6 sec
# Epoch 5/100  | val_loss: 1.53 - val_rmse: 1.24 - val_mae: 0.92 - took 19.9 sec
# Epoch 6/100  | val_loss: 1.52 - val_rmse: 1.23 - val_mae: 0.91 - took 19.8 sec
# Epoch 7/100  | val_loss: 1.51 - val_rmse: 1.23 - val_mae: 0.91 - took 19.7 sec
# Epoch 8/100  | val_loss: 1.50 - val_rmse: 1.22 - val_mae: 0.91 - took 20.0 sec
# Epoch 9/100  | val_loss: 1.49 - val_rmse: 1.22 - val_mae: 0.90 - took 19.7 sec
# Epoch 10/100 | val_loss: 1.49 - val_rmse: 1.22 - val_mae: 0.90 - took 19.6 sec
# Epoch 11/100 | val_loss: 1.48 - val_rmse: 1.22 - val_mae: 0.90 - took 20.1 sec
# Epoch 12/100 | val_loss: 1.48 - val_rmse: 1.22 - val_mae: 0.90 - took 19.8 sec
# Epoch 13/100 | val_loss: 1.47 - val_rmse: 1.21 - val_mae: 0.89 - took 19.7 sec
# Epoch 14/100 | val_loss: 1.47 - val_rmse: 1.21 - val_mae: 0.89 - took 19.9 sec
# Epoch 15/100 | val_loss: 1.47 - val_rmse: 1.21 - val_mae: 0.89 - took 19.8 sec
# Epoch 16/100 | val_loss: 1.47 - val_rmse: 1.21 - val_mae: 0.89 - took 19.5 sec
# Epoch 17/100 | val_loss: 1.46 - val_rmse: 1.21 - val_mae: 0.89 - took 19.6 sec
# Epoch 18/100 | val_loss: 1.46 - val_rmse: 1.21 - val_mae: 0.89 - took 19.5 sec
#
# Training took 6 min and 39 sec

# %%
pred = svd.predict(tt)

# %%
np.std(pred)
# Out:
# 0.608141692822937

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(tt['rating'], pred)
print(f'Test MAE: {mae:.2f}')
# Out:
# Test MAE: 0.89

# %%
from sklearn.metrics import mean_squared_error
mae = mean_squared_error(tt['rating'], pred)
print(f'Test R2: {mae:.2f}')
# Out:
# Test R2: 1.46

# %%
tt2[tt2["i_id"] == 64463]
# Out:
#              u_id   i_id  rating      pred
# 219110914  614889  64463       0  2.703639
# 160041914  333158  64463       5  2.929363
# 81006517   163126  64463       3  2.498137
# 116518749  238516  64463       3  3.228669
# 167012666  348800  64463       4  2.685673
# ...           ...    ...     ...       ...
# 135196145  278837  64463       0  3.327827
# 78925248   158838  64463       4  2.258565
# 130686550  269012  64463       4  2.822786
# 209756313  437864  64463       3  3.288372
# 43291475    86218  64463       5  3.072994
#
# [216 rows x 4 columns]
